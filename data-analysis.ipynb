# %% [markdown]
# <a href="https://colab.research.google.com/github/sessex/billboard-sentiment-analysis/blob/master/data-analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Billboard Hot 100 Sentiment Analysis**
# Sentiment analysis of the lyrics from Billboard Hot 100 songs from 1965-2015. NLP was used to evaluate the emotion of each word in the song and assign each song an emotion rating based on the proportion between number of words with given emotion to total word count. Results were explored and visualized using d3.js at the link below.
#
# Final visualization: https://observablehq.com/d/9f91ebecdcb70699

# %% [markdown]
# # **Import tools & files**

# %%
import pandas as pd
import nltk 
nltk.download('punkt')
from nltk import tokenize
from nltk import word_tokenize
from nltk.stem.snowball import SnowballStemmer

import numpy as np

from tqdm import tqdm_notebook as tqdm
from tqdm import trange
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
allBillboardHot100 = pd.read_csv('billboard_lyrics_1964-2015.csv', encoding='latin-1')

# %%
allBillboardHot100.head()
# Out:
#    Rank  ... Source
# 0     1  ...    3.0
# 1     2  ...    1.0
# 2     3  ...    1.0
# 3     4  ...    1.0
# 4     5  ...    1.0
#
# [5 rows x 6 columns]

# %% [markdown]
# # **Create dataframe that calculates sentiment values for each song based on lyrics**

# %%
def text_emotion(df, column):
  new_df = df.copy()
  
  emolex_df = pd.read_csv('NRC-Emotion-Lexicon-Wordlevel-v0.92.txt',
                          names=["words", "emotion", "association"],
                          sep='\t')
  emolex_words = emolex_df.pivot(index='words',
                                 columns='emotion',
                                 values='association').reset_index()
  
  emotions = emolex_words.columns.drop('words')
  emo_df = pd.DataFrame(0, index=df.index, columns=emotions)

  stemmer = SnowballStemmer("english")

  with tqdm(total=len(list(new_df.iterrows()))) as pbar:
    for i, row in new_df.iterrows():
      pbar.update(1)
      lyrics_string = str(new_df.loc[i][column])
      lyrics = word_tokenize(lyrics_string)
      if lyrics != '':
        for word in lyrics:      
          word = stemmer.stem(word.lower())
          emo_score = emolex_words[emolex_words.words == word]
          if not emo_score.empty:
            for emotion in list(emotions):
              emo_df.at[i, emotion] += emo_score[emotion]

  new_df = pd.concat([new_df, emo_df], axis=1)
  return new_df

# %%
billboard_df = text_emotion(allBillboardHot100, 'Lyrics')
# Out:
# HBox(children=(IntProgress(value=0, max=5100), HTML(value='')))

# %%
billboard_df.head()
# Out:
#    Rank                                      Song  ... surprise  trust
# 0     1                               wooly bully  ...        0      0
# 1     2  i cant help myself sugar pie honey bunch  ...        1      0
# 2     3                i cant get no satisfaction  ...        0      0
# 3     4                       you were on my mind  ...        0      0
# 4     5              youve lost that lovin feelin  ...        2      2
#
# [5 rows x 16 columns]

# %% [markdown]
# # **Normalize sentiment values by song's word count**

# %%
billboard_df['word_count'] = billboard_df['Lyrics'].apply(str).apply(tokenize.word_tokenize).apply(len)

# %%
billboard_df.head()
# Out:
#    Rank                                      Song  ... trust  word_count
# 0     1                               wooly bully  ...     0         125
# 1     2  i cant help myself sugar pie honey bunch  ...     0         205
# 2     3                i cant get no satisfaction  ...     0           0
# 3     4                       you were on my mind  ...     0         152
# 4     5              youve lost that lovin feelin  ...     2         232
#
# [5 rows x 17 columns]

# %%
emotions = ['anger', 'anticipation', 'disgust', 'fear', 'joy', 'negative', 'positive', 'sadness', 'surprise', 'trust']

# %%
for emotion in emotions:
  billboard_df[emotion] = billboard_df[emotion] / billboard_df['word_count']

# %%
billboard_df.head()
# Out:
#    Rank                                      Song  ...     trust  word_count
# 0     1                               wooly bully  ...  0.000000         125
# 1     2  i cant help myself sugar pie honey bunch  ...  0.000000         205
# 2     3                i cant get no satisfaction  ...       NaN           0
# 3     4                       you were on my mind  ...  0.000000         152
# 4     5              youve lost that lovin feelin  ...  0.008621         232
#
# [5 rows x 17 columns]

# %% [markdown]
# # **Clean results**

# %%
billboard_df['Lyrics'].replace('', np.nan, inplace=True)
billboard_df.head()
# Out:
#    Rank                                      Song  ...     trust  word_count
# 0     1                               wooly bully  ...  0.000000         125
# 1     2  i cant help myself sugar pie honey bunch  ...  0.000000         205
# 3     4                       you were on my mind  ...  0.000000         152
# 4     5              youve lost that lovin feelin  ...  0.008621         232
# 5     6                                  downtown  ...  0.008333         240
#
# [5 rows x 17 columns]

# %%
billboard_df.dropna(inplace=True)

# %% [markdown]
# # **Export results**

# %%
# Download to google drive
from google.colab import drive
drive.mount('drive')

# %%
billboard_df.to_csv('billboard_sentiment_analysis.csv')
# !cp billboard_sentiment_analysis.csv "drive/My Drive/"

# %% [markdown]
# # **Additional: Compare songs ranked #1**

# %%
rankOne_df = billboard_df[billboard_df.Rank == 1]
rankOne_df
# Out:
#       Rank                                        Song  ...     trust  word_count
# 0        1                                 wooly bully  ...  0.000000         125
# 200      1                            to sir with love  ...  0.042857         140
# 300      1                                    hey jude  ...  0.010676         281
# 400      1                                 sugar sugar  ...  0.035176         199
# 500      1                  bridge over troubled water  ...  0.024540         163
# 600      1                            joy to the world  ...  0.015267         262
# 700      1         the first time ever i saw your face  ...  0.036765         136
# 800      1  tie a yellow ribbon round the ole oak tree  ...  0.051370         292
# 900      1                             the way we were  ...  0.015385         130
# 1000     1                  love will keep us together  ...  0.008621         232
# 1100     1                            silly love songs  ...  0.018957         211
# 1200     1         tonights the night gonna be alright  ...  0.031646         158
# 1300     1                              shadow dancing  ...  0.005000         400
# 1400     1                                  my sharona  ...  0.014634         205
# 1500     1                                     call me  ...  0.029661         236
# 1600     1                            bette davis eyes  ...  0.008621         232
# 1700     1                                    physical  ...  0.011278         266
# 1800     1                       every breath you take  ...  0.039039         333
# 1900     1                              when doves cry  ...  0.080229         349
# 2000     1                            careless whisper  ...  0.040115         349
# 2200     1                       walk like an egyptian  ...  0.019920         251
# 2300     1                                       faith  ...  0.086093         302
# 2400     1                                   look away  ...  0.013661         366
# 2500     1                                     hold on  ...  0.002513         398
# 2600     1             everything i do i do it for you  ...  0.012876         233
# 2700     1                             end of the road  ...  0.000000         513
# 2800     1                      i will always love you  ...  0.027778         144
# 2900     1                                    the sign  ...  0.003663         273
# 3000     1                           gangstas paradise  ...  0.014028         499
# 3100     1                   macarena bayside boys mix  ...  0.000000         399
# 3300     1                                   too close  ...  0.036170         470
# 3400     1                                     believe  ...  0.003378         296
# 3500     1                                     breathe  ...  0.004065         246
# 3600     1                         hanging by a moment  ...  0.007722         259
# 3700     1                           how you remind me  ...  0.010989         364
# 3800     1                                  in da club  ...  0.030000         700
# 3900     1                                        yeah  ...  0.010017         599
# 4000     1                          we belong together  ...  0.010776         464
# 4100     1                                     bad day  ...  0.026810         373
# 4200     1                               irreplaceable  ...  0.009843         508
# 4300     1                                         low  ...  0.013393         672
# 4400     1                               boom boom pow  ...  0.004090         489
# 4500     1                                     tik tok  ...  0.002445         409
# 4600     1                         rolling in the deep  ...  0.010309         582
# 4700     1                somebody that i used to know  ...  0.026385         379
# 4800     1                                 thrift shop  ...  0.030945         614
# 4900     1                                       happy  ...  0.062249         498
# 5000     1                                 uptown funk  ...  0.019366         568
#
# [48 rows x 17 columns]
